# %%
import sys #not import phyton pd de kütüphane eklemeye yarayan komut bloğudur // sys sistem versiyonu dur
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
print("Merhaba, igü - İstka")
# Out:
# Merhaba, igü - İstka

# %%
k=str(print("selam"))
k
# Out:
# selam
# 'None'

# %%
from google.colab import drive #collab driveden çalışacak drvie adresini aşağ yazdık

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os #operating syste mkütüpane dahil oldu dosya konumlandırma kodudur chdir
os.chdir('/content/drive/My Drive/VERIYAPILARI_ISKA')
# !pwd #bize kodun çıktısını dosya yolu olarak veren kod bloğğudur
# Out:
# /content/drive/My Drive/VERIYAPILARI_ISKA
