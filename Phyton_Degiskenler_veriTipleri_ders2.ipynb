# %%
print("merhaba,İgü -itska/ Ders 3")
# Out:
# merhaba,İgü -itska/ Ders 3

# %%
import sys #import phyton programlama dilinde yazılıma kütüphane eklemeye yarayan bir kod bloğudur
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
from google.colab import drive # google colab - drive bağlantısı

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.chdir('/content/drive/My Drive/VERIYAPILARI_ISKA')

# !pwd # bize kodun çıktısını dosya yolu olarak veren kod blogudur.
# Out:
# /content/drive/My Drive/VERIYAPILARI_ISKA

# %%
# Geçerli değişken tanımlaması
ücret_1 = 10
ücret2 = 20
_ücret3 = 30

# %%
#Geçersiz değişken tanımlaması
#1degisken = 40
#degisken-4 = 50

# %%
b=c=20.5
print(b)
print(c)
# Out:
# 20.5
# 20.5

# %%
# Değişken Tanımlama İşlemi

x = 5
y = "Merhaba Dünya"

print(x)
print(y)
# Out:
# 5
# Merhaba Dünya

# %%
# Integer - Tamsayı tanımlaması

a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
# Float - Ondalıklı Sayı tanımlaması

b = 20.5
print(type(b))
# Out:
# <class 'float'>

# %%
# String - Metinsel içerik tanımlaması

c = "Python Programlama"
print(c)
print(type(c))
# Out:
# Python Programlama
# <class 'str'>

# %%
# Boolean (True - False) - Doğru / Yanlış tanımlaması

d = True
e = False
print(d)
print(type(e))
# Out:
# True
# <class 'bool'>

# %%
#int ten float a cevrimin gerçekleşmesi
x=10
y=float(x)
print(y,type(y))
print(x,type(x))
# Out:
# 10.0 <class 'float'>
# 10 <class 'int'>

# %%
# float'tan int'e çevrimin gerçekleştirilmesi
a = 12.34
b = int(a)
print(b, type(b))
# Out:
# 12 <class 'int'>

# %%
# List - Liste dizi tanımlaması

my_list = [1, 2, 3, 4, 5]
print(type(my_list))
print(my_list)
print(my_list[1])
# Out:
# <class 'list'>
# [1, 2, 3, 4, 5]
# 2

# %%
names=["ali","veli","ahmet"]
print(names[1])
# Out:
# veli

# %%
# Tuple - Demet tanımlaması genelde sunucular üzerinde çalışacaksanız demet kullanılır

my_tuple = (1, 2, 3, 4, 5)
print(type(my_tuple))
print(my_tuple)
print(my_tuple[1])
# Out:
# <class 'tuple'>
# (1, 2, 3, 4, 5)
# 2

# %%
from posixpath import split
ad="serhat"

print(split(ad))
# Out:
# ('', 'serhat')

# %%
a="merhaba"
print(len(a))
# Out:
# 7

# %%
liste ="SELAMLAR"

liste.capitalize()
# Out:
# 'Selamlar'

# %%
liste1 ="selamlar"

#liste1.upper()

print(liste1.upper())
# Out:
# SELAMLAR

# %%
x=-50
print(abs(x))
# Out:
# 50

# %%
# Dictionary - Sözlük Örneği -> Öğrencilerin notlarını tutan bir sözlük
notlar={
    "ali":85,
    "veli":90,
    "ayşe":75
}
notlar["fatma"]=92  # Yeni öğrenci ekleme
notlar["ali"]=88  # Bir öğrencinin notunu güncelleme
print(notlar)
# Out:
# {'ali': 88, 'veli': 90, 'ayşe': 75, 'fatma': 92}

# %% [markdown]
# Sözlük Metotları
#
# keys(): Sözlüğün anahtarlarını döner.
# values(): Sözlüğün değerlerini döner.
# items(): Sözlüğün anahtar-değer çiftlerini döner.

# %%
print(notlar.keys())
print(notlar.values())
print(notlar.items())
# Out:
# dict_keys(['ali', 'veli', 'ayşe', 'fatma'])
# dict_values([88, 90, 75, 92])
# dict_items([('ali', 88), ('veli', 90), ('ayşe', 75), ('fatma', 92)])

# %% [markdown]
# Set - Küme Nedir?
#
# Kümeler, benzersiz elemanlardan oluşan sırasız koleksiyonlardır.
# Kümeler değiştirilebilir ve tekrarlayan eleman içermez.
# Küme Metotları
#
# add(): Küme içerisine eleman ekler.
# remove(): Küme içerisinden eleman siler.
# union(): İki kümenin birleşimini döner.
# intersection(): İki kümenin kesişimini döner.
# difference(): İki kümenin farkını döner.

# %%
# Set - Küme Örneği -> Bir yazılım etkinliğine katılan kişilerin oluşturduğu kümeler

kodyazanlar={"ahmet","mehmet","ayşe"}
kodyazmayanlar={"ayşe","fatma","veli"}

# Kafasına Göre Takılan Öğrenciler
ortak=kodyazanlar.intersection(kodyazmayanlar)
print("kafasına göre takılan öğrenci listesi:",ortak)

# Etkinlikte Kod Yazmayan Öğrencilerin Tespiti
Kod_yazmayan=kodyazmayanlar.difference(kodyazanlar)
print("kod yazmayan öğrenci listesi:",Kod_yazmayan)

# Yazılım Eğitiminin Öğrenci İmza Listesi
imza_listesi=kodyazanlar.union(kodyazmayanlar)
print("imza listesi:",imza_listesi)

kodyazanlar.add("samet")
print(kodyazanlar)
kodyazanlar.remove("mehmet")
print(kodyazanlar)
# Out:
# kafasına göre takılan öğrenci listesi: {'ayşe'}
# kod yazmayan öğrenci listesi: {'veli', 'fatma'}
# imza listesi: {'mehmet', 'ahmet', 'fatma', 'veli', 'ayşe'}
# {'samet', 'mehmet', 'ayşe', 'ahmet'}
# {'samet', 'ayşe', 'ahmet'}

# %%
giris=input("lütfen bir sayı giriniz: ")
try:
  num=float(giris)
  print(f"girilen sayı: {num} ,tipi {type(num)},",abs(num))
except ValueError:
  print("lütfen geçerli sayı giriniz")
# Out:
# lütfen bir sayı giriniz: -6
# girilen sayı: -6.0 ,tipi <class 'float'>, 6.0
